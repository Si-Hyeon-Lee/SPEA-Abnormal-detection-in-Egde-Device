# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score

from xgboost import XGBClassifier
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from pytorch_tabnet.tab_model import TabNetClassifier

df = pd.read_csv("./spea_data_nvme/spea_pass_fail_data.csv")
X = df.iloc[:, :-1].values.astype(np.float32)
y = df.iloc[:, -1].values.astype(np.int64)

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

print(X_train.shape,X_val.shape)
# Out:
# (8799999, 28) (2200000, 28)

# %%
xgb = XGBClassifier(
    n_estimators=1000, # early stopping 걸면 1000도 충분
    max_depth=4, # 휴리스틱하게 결정.
    learning_rate=0.03,
    subsample=0.7,
    colsample_bytree=0.7,
    min_child_weight=10,
    gamma=1.0,
    reg_alpha=0.1,
    reg_lambda=1.0,
    objective="binary:logistic",
    eval_metric="auc",
    tree_method="gpu_hist",
    random_state=42
)

xgb.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    early_stopping_rounds=50,
    verbose=10,
)

xgb.save_model('./save/XGB/xgb.model')
xgb_pred = (xgb.predict_proba(X_val)[:, 1] > 0.5).astype(int)
print("XGBoost: Accuracy:", accuracy_score(y_val, xgb_pred))
print("XGBoost: ROC-AUC :", roc_auc_score(y_val, xgb.predict_proba(X_val)[:, 1]))
# Out:
# [0]	validation_0-auc:0.73445
# [1]	validation_0-auc:0.74109
# [2]	validation_0-auc:0.75071
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [06:12:26] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [3]	validation_0-auc:0.75422
# [4]	validation_0-auc:0.75720
# [5]	validation_0-auc:0.76507
# [6]	validation_0-auc:0.76461
# [7]	validation_0-auc:0.76595
# [8]	validation_0-auc:0.76714
# [9]	validation_0-auc:0.76779
# [10]	validation_0-auc:0.76817
# [11]	validation_0-auc:0.76846
# [12]	validation_0-auc:0.77100
# [13]	validation_0-auc:0.77147
# [14]	validation_0-auc:0.77278
# [15]	validation_0-auc:0.77446
# [16]	validation_0-auc:0.77478
# [17]	validation_0-auc:0.77574
# [18]	validation_0-auc:0.77665
# [19]	validation_0-auc:0.77722
# [20]	validation_0-auc:0.77742
# [21]	validation_0-auc:0.77899
# [22]	validation_0-auc:0.77962
# [23]	validation_0-auc:0.78094
# [24]	validation_0-auc:0.78142
# [25]	validation_0-auc:0.78189
# [26]	validation_0-auc:0.78247
# [27]	validation_0-auc:0.78268
# [28]	validation_0-auc:0.78327
# [29]	validation_0-auc:0.78387
# [30]	validation_0-auc:0.78431
# [31]	validation_0-auc:0.78538
# [32]	validation_0-auc:0.78578
# [33]	validation_0-auc:0.78621
# [34]	validation_0-auc:0.78681
# [35]	validation_0-auc:0.78706
# [36]	validation_0-auc:0.78758
# [37]	validation_0-auc:0.78831
# [38]	validation_0-auc:0.78868
# [39]	validation_0-auc:0.78894
# [40]	validation_0-auc:0.78926
# [41]	validation_0-auc:0.78995
# [42]	validation_0-auc:0.79049
# [43]	validation_0-auc:0.79107
# [44]	validation_0-auc:0.79154
# [45]	validation_0-auc:0.79187
# [46]	validation_0-auc:0.79234
# [47]	validation_0-auc:0.79262
# [48]	validation_0-auc:0.79288
# [49]	validation_0-auc:0.79314
# [50]	validation_0-auc:0.79351
# [51]	validation_0-auc:0.79369
# [52]	validation_0-auc:0.79404
# [53]	validation_0-auc:0.79451
# [54]	validation_0-auc:0.79492
# [55]	validation_0-auc:0.79529
# [56]	validation_0-auc:0.79559
# [57]	validation_0-auc:0.79600
# [58]	validation_0-auc:0.79633
# [59]	validation_0-auc:0.79666
# [60]	validation_0-auc:0.79702
# [61]	validation_0-auc:0.79735
# [62]	validation_0-auc:0.79766
# [63]	validation_0-auc:0.79795
# [64]	validation_0-auc:0.79828
# [65]	validation_0-auc:0.79858
# [66]	validation_0-auc:0.79893
# [67]	validation_0-auc:0.79919
# [68]	validation_0-auc:0.79944
# [69]	validation_0-auc:0.79958
# [70]	validation_0-auc:0.79977
# [71]	validation_0-auc:0.80007
# [72]	validation_0-auc:0.80033
# [73]	validation_0-auc:0.80056
# [74]	validation_0-auc:0.80085
# [75]	validation_0-auc:0.80105
# [76]	validation_0-auc:0.80126
# [77]	validation_0-auc:0.80139
# [78]	validation_0-auc:0.80155
# [79]	validation_0-auc:0.80178
# [80]	validation_0-auc:0.80193
# [81]	validation_0-auc:0.80210
# [82]	validation_0-auc:0.80235
# [83]	validation_0-auc:0.80253
# [84]	validation_0-auc:0.80275
# [85]	validation_0-auc:0.80300
# [86]	validation_0-auc:0.80311
# [87]	validation_0-auc:0.80331
# [88]	validation_0-auc:0.80343
# [89]	validation_0-auc:0.80355
# [90]	validation_0-auc:0.80372
# [91]	validation_0-auc:0.80389
# [92]	validation_0-auc:0.80404
# [93]	validation_0-auc:0.80416
# [94]	validation_0-auc:0.80439
# [95]	validation_0-auc:0.80455
# [96]	validation_0-auc:0.80468
# [97]	validation_0-auc:0.80484
# [98]	validation_0-auc:0.80497
# [99]	validation_0-auc:0.80512
# [100]	validation_0-auc:0.80533
# [101]	validation_0-auc:0.80543
# [102]	validation_0-auc:0.80557
# [103]	validation_0-auc:0.80568
# [104]	validation_0-auc:0.80585
# [105]	validation_0-auc:0.80598
# [106]	validation_0-auc:0.80605
# [107]	validation_0-auc:0.80615
# [108]	validation_0-auc:0.80629
# [109]	validation_0-auc:0.80641
# [110]	validation_0-auc:0.80652
# [111]	validation_0-auc:0.80665
# [112]	validation_0-auc:0.80676
# [113]	validation_0-auc:0.80693
# [114]	validation_0-auc:0.80706
# [115]	validation_0-auc:0.80717
# [116]	validation_0-auc:0.80725
# [117]	validation_0-auc:0.80735
# [118]	validation_0-auc:0.80747
# [119]	validation_0-auc:0.80757
# [120]	validation_0-auc:0.80765
# [121]	validation_0-auc:0.80773
# [122]	validation_0-auc:0.80781
# [123]	validation_0-auc:0.80790
# [124]	validation_0-auc:0.80805
# [125]	validation_0-auc:0.80814
# [126]	validation_0-auc:0.80822
# [127]	validation_0-auc:0.80831
# [128]	validation_0-auc:0.80842
# [129]	validation_0-auc:0.80852
# [130]	validation_0-auc:0.80867
# [131]	validation_0-auc:0.80874
# [132]	validation_0-auc:0.80886
# [133]	validation_0-auc:0.80896
# [134]	validation_0-auc:0.80912
# [135]	validation_0-auc:0.80921
# [136]	validation_0-auc:0.80930
# [137]	validation_0-auc:0.80939
# [138]	validation_0-auc:0.80944
# [139]	validation_0-auc:0.80959
# [140]	validation_0-auc:0.80965
# [141]	validation_0-auc:0.80972
# [142]	validation_0-auc:0.80981
# [143]	validation_0-auc:0.80990
# [144]	validation_0-auc:0.81003
# [145]	validation_0-auc:0.81011
# [146]	validation_0-auc:0.81020
# [147]	validation_0-auc:0.81027
# [148]	validation_0-auc:0.81035
# [149]	validation_0-auc:0.81044
# [150]	validation_0-auc:0.81049
# [151]	validation_0-auc:0.81051
# [152]	validation_0-auc:0.81061
# [153]	validation_0-auc:0.81066
# [154]	validation_0-auc:0.81075
# [155]	validation_0-auc:0.81081
# [156]	validation_0-auc:0.81087
# [157]	validation_0-auc:0.81096
# [158]	validation_0-auc:0.81103
# [159]	validation_0-auc:0.81110
# [160]	validation_0-auc:0.81118
# [161]	validation_0-auc:0.81125
# [162]	validation_0-auc:0.81134
# [163]	validation_0-auc:0.81140
# [164]	validation_0-auc:0.81148
# [165]	validation_0-auc:0.81153
# [166]	validation_0-auc:0.81158
# [167]	validation_0-auc:0.81162
# [168]	validation_0-auc:0.81167
# [169]	validation_0-auc:0.81176
# [170]	validation_0-auc:0.81186
# [171]	validation_0-auc:0.81200
# [172]	validation_0-auc:0.81204
# [173]	validation_0-auc:0.81213
# [174]	validation_0-auc:0.81219
# [175]	validation_0-auc:0.81226
# [176]	validation_0-auc:0.81235
# [177]	validation_0-auc:0.81240
# [178]	validation_0-auc:0.81244
# [179]	validation_0-auc:0.81251
# [180]	validation_0-auc:0.81258
# [181]	validation_0-auc:0.81264
# [182]	validation_0-auc:0.81272
# [183]	validation_0-auc:0.81275
# [184]	validation_0-auc:0.81282
# [185]	validation_0-auc:0.81286
# [186]	validation_0-auc:0.81293
# [187]	validation_0-auc:0.81303
# [188]	validation_0-auc:0.81308
# [189]	validation_0-auc:0.81311
# [190]	validation_0-auc:0.81318
# [191]	validation_0-auc:0.81323
# [192]	validation_0-auc:0.81328
# [193]	validation_0-auc:0.81333
# [194]	validation_0-auc:0.81338
# [195]	validation_0-auc:0.81343
# [196]	validation_0-auc:0.81348
# [197]	validation_0-auc:0.81351
# [198]	validation_0-auc:0.81355
# [199]	validation_0-auc:0.81359
# [200]	validation_0-auc:0.81362
# [201]	validation_0-auc:0.81366
# [202]	validation_0-auc:0.81374
# [203]	validation_0-auc:0.81377
# [204]	validation_0-auc:0.81379
# [205]	validation_0-auc:0.81386
# [206]	validation_0-auc:0.81392
# [207]	validation_0-auc:0.81402
# [208]	validation_0-auc:0.81411
# [209]	validation_0-auc:0.81418
# [210]	validation_0-auc:0.81423
# [211]	validation_0-auc:0.81426
# [212]	validation_0-auc:0.81431
# [213]	validation_0-auc:0.81436
# [214]	validation_0-auc:0.81439
# [215]	validation_0-auc:0.81445
# [216]	validation_0-auc:0.81449
# [217]	validation_0-auc:0.81452
# [218]	validation_0-auc:0.81460
# [219]	validation_0-auc:0.81463
# [220]	validation_0-auc:0.81469
# [221]	validation_0-auc:0.81474
# [222]	validation_0-auc:0.81480
# [223]	validation_0-auc:0.81483
# [224]	validation_0-auc:0.81490
# [225]	validation_0-auc:0.81492
# [226]	validation_0-auc:0.81495
# [227]	validation_0-auc:0.81498
# [228]	validation_0-auc:0.81504
# [229]	validation_0-auc:0.81506
# [230]	validation_0-auc:0.81513
# [231]	validation_0-auc:0.81517
# [232]	validation_0-auc:0.81520
# [233]	validation_0-auc:0.81522
# [234]	validation_0-auc:0.81523
# [235]	validation_0-auc:0.81528
# [236]	validation_0-auc:0.81534
# [237]	validation_0-auc:0.81539
# [238]	validation_0-auc:0.81543
# [239]	validation_0-auc:0.81547
# [240]	validation_0-auc:0.81549
# [241]	validation_0-auc:0.81555
# [242]	validation_0-auc:0.81561
# [243]	validation_0-auc:0.81567
# [244]	validation_0-auc:0.81570
# [245]	validation_0-auc:0.81576
# [246]	validation_0-auc:0.81577
# [247]	validation_0-auc:0.81580
# [248]	validation_0-auc:0.81586
# [249]	validation_0-auc:0.81590
# [250]	validation_0-auc:0.81595
# [251]	validation_0-auc:0.81598
# [252]	validation_0-auc:0.81606
# [253]	validation_0-auc:0.81612
# [254]	validation_0-auc:0.81616
# [255]	validation_0-auc:0.81622
# [256]	validation_0-auc:0.81624
# [257]	validation_0-auc:0.81630
# [258]	validation_0-auc:0.81633
# [259]	validation_0-auc:0.81638
# [260]	validation_0-auc:0.81641
# [261]	validation_0-auc:0.81646
# [262]	validation_0-auc:0.81652
# [263]	validation_0-auc:0.81655
# [264]	validation_0-auc:0.81660
# [265]	validation_0-auc:0.81663
# [266]	validation_0-auc:0.81669
# [267]	validation_0-auc:0.81671
# [268]	validation_0-auc:0.81674
# [269]	validation_0-auc:0.81676
# [270]	validation_0-auc:0.81678
# [271]	validation_0-auc:0.81683
# [272]	validation_0-auc:0.81688
# [273]	validation_0-auc:0.81691
# [274]	validation_0-auc:0.81694
# [275]	validation_0-auc:0.81702
# [276]	validation_0-auc:0.81703
# [277]	validation_0-auc:0.81705
# [278]	validation_0-auc:0.81710
# [279]	validation_0-auc:0.81715
# [280]	validation_0-auc:0.81722
# [281]	validation_0-auc:0.81727
# [282]	validation_0-auc:0.81735
# [283]	validation_0-auc:0.81737
# [284]	validation_0-auc:0.81742
# [285]	validation_0-auc:0.81749
# [286]	validation_0-auc:0.81752
# [287]	validation_0-auc:0.81754
# [288]	validation_0-auc:0.81759
# [289]	validation_0-auc:0.81768
# [290]	validation_0-auc:0.81771
# [291]	validation_0-auc:0.81774
# [292]	validation_0-auc:0.81776
# [293]	validation_0-auc:0.81781
# [294]	validation_0-auc:0.81782
# [295]	validation_0-auc:0.81786
# [296]	validation_0-auc:0.81789
# [297]	validation_0-auc:0.81792
# [298]	validation_0-auc:0.81795
# [299]	validation_0-auc:0.81798
# [300]	validation_0-auc:0.81802
# [301]	validation_0-auc:0.81804
# [302]	validation_0-auc:0.81806
# [303]	validation_0-auc:0.81809
# [304]	validation_0-auc:0.81815
# [305]	validation_0-auc:0.81820
# [306]	validation_0-auc:0.81823
# [307]	validation_0-auc:0.81826
# [308]	validation_0-auc:0.81827
# [309]	validation_0-auc:0.81830
# [310]	validation_0-auc:0.81833
# [311]	validation_0-auc:0.81840
# [312]	validation_0-auc:0.81844
# [313]	validation_0-auc:0.81847
# [314]	validation_0-auc:0.81851
# [315]	validation_0-auc:0.81856
# [316]	validation_0-auc:0.81860
# [317]	validation_0-auc:0.81861
# [318]	validation_0-auc:0.81866
# [319]	validation_0-auc:0.81868
# [320]	validation_0-auc:0.81873
# [321]	validation_0-auc:0.81876
# [322]	validation_0-auc:0.81880
# [323]	validation_0-auc:0.81884
# [324]	validation_0-auc:0.81888
# [325]	validation_0-auc:0.81891
# [326]	validation_0-auc:0.81895
# [327]	validation_0-auc:0.81899
# [328]	validation_0-auc:0.81900
# [329]	validation_0-auc:0.81903
# [330]	validation_0-auc:0.81906
# [331]	validation_0-auc:0.81909
# [332]	validation_0-auc:0.81910
# [333]	validation_0-auc:0.81913
# [334]	validation_0-auc:0.81915
# [335]	validation_0-auc:0.81918
# [336]	validation_0-auc:0.81920
# [337]	validation_0-auc:0.81921
# [338]	validation_0-auc:0.81924
# [339]	validation_0-auc:0.81929
# [340]	validation_0-auc:0.81933
# [341]	validation_0-auc:0.81936
# [342]	validation_0-auc:0.81940
# [343]	validation_0-auc:0.81941
# [344]	validation_0-auc:0.81944
# [345]	validation_0-auc:0.81948
# [346]	validation_0-auc:0.81952
# [347]	validation_0-auc:0.81956
# [348]	validation_0-auc:0.81960
# [349]	validation_0-auc:0.81964
# [350]	validation_0-auc:0.81967
# [351]	validation_0-auc:0.81970
# [352]	validation_0-auc:0.81972
# [353]	validation_0-auc:0.81973
# [354]	validation_0-auc:0.81974
# [355]	validation_0-auc:0.81975
# [356]	validation_0-auc:0.81979
# [357]	validation_0-auc:0.81980
# [358]	validation_0-auc:0.81981
# [359]	validation_0-auc:0.81985
# [360]	validation_0-auc:0.81989
# [361]	validation_0-auc:0.81989
# [362]	validation_0-auc:0.81993
# [363]	validation_0-auc:0.81996
# [364]	validation_0-auc:0.81999
# [365]	validation_0-auc:0.82002
# [366]	validation_0-auc:0.82005
# [367]	validation_0-auc:0.82009
# [368]	validation_0-auc:0.82011
# [369]	validation_0-auc:0.82012
# [370]	validation_0-auc:0.82017
# [371]	validation_0-auc:0.82020
# [372]	validation_0-auc:0.82023
# [373]	validation_0-auc:0.82027
# [374]	validation_0-auc:0.82032
# [375]	validation_0-auc:0.82037
# [376]	validation_0-auc:0.82040
# [377]	validation_0-auc:0.82041
# [378]	validation_0-auc:0.82043
# [379]	validation_0-auc:0.82043
# [380]	validation_0-auc:0.82046
# [381]	validation_0-auc:0.82049
# [382]	validation_0-auc:0.82054
# [383]	validation_0-auc:0.82060
# [384]	validation_0-auc:0.82063
# [385]	validation_0-auc:0.82064
# [386]	validation_0-auc:0.82066
# [387]	validation_0-auc:0.82067
# [388]	validation_0-auc:0.82070
# [389]	validation_0-auc:0.82073
# [390]	validation_0-auc:0.82074
# [391]	validation_0-auc:0.82082
# [392]	validation_0-auc:0.82086
# [393]	validation_0-auc:0.82090
# [394]	validation_0-auc:0.82092
# [395]	validation_0-auc:0.82094
# [396]	validation_0-auc:0.82096
# [397]	validation_0-auc:0.82098
# [398]	validation_0-auc:0.82102
# [399]	validation_0-auc:0.82108
# [400]	validation_0-auc:0.82109
# [401]	validation_0-auc:0.82111
# [402]	validation_0-auc:0.82115
# [403]	validation_0-auc:0.82116
# [404]	validation_0-auc:0.82118
# [405]	validation_0-auc:0.82122
# [406]	validation_0-auc:0.82126
# [407]	validation_0-auc:0.82129
# [408]	validation_0-auc:0.82131
# [409]	validation_0-auc:0.82133
# [410]	validation_0-auc:0.82135
# [411]	validation_0-auc:0.82137
# [412]	validation_0-auc:0.82138
# [413]	validation_0-auc:0.82141
# [414]	validation_0-auc:0.82143
# [415]	validation_0-auc:0.82145
# [416]	validation_0-auc:0.82147
# [417]	validation_0-auc:0.82150
# [418]	validation_0-auc:0.82152
# [419]	validation_0-auc:0.82155
# [420]	validation_0-auc:0.82156
# [421]	validation_0-auc:0.82162
# [422]	validation_0-auc:0.82162
# [423]	validation_0-auc:0.82166
# [424]	validation_0-auc:0.82168
# [425]	validation_0-auc:0.82171
# [426]	validation_0-auc:0.82172
# [427]	validation_0-auc:0.82177
# [428]	validation_0-auc:0.82178
# [429]	validation_0-auc:0.82183
# [430]	validation_0-auc:0.82186
# [431]	validation_0-auc:0.82187
# [432]	validation_0-auc:0.82189
# [433]	validation_0-auc:0.82192
# [434]	validation_0-auc:0.82195
# [435]	validation_0-auc:0.82197
# [436]	validation_0-auc:0.82201
# [437]	validation_0-auc:0.82203
# [438]	validation_0-auc:0.82204
# [439]	validation_0-auc:0.82206
# [440]	validation_0-auc:0.82209
# [441]	validation_0-auc:0.82211
# [442]	validation_0-auc:0.82214
# [443]	validation_0-auc:0.82218
# [444]	validation_0-auc:0.82219
# [445]	validation_0-auc:0.82222
# [446]	validation_0-auc:0.82223
# [447]	validation_0-auc:0.82226
# [448]	validation_0-auc:0.82227
# [449]	validation_0-auc:0.82228
# [450]	validation_0-auc:0.82231
# [451]	validation_0-auc:0.82233
# [452]	validation_0-auc:0.82235
# [453]	validation_0-auc:0.82238
# [454]	validation_0-auc:0.82240
# [455]	validation_0-auc:0.82243
# [456]	validation_0-auc:0.82245
# [457]	validation_0-auc:0.82246
# [458]	validation_0-auc:0.82253
# [459]	validation_0-auc:0.82254
# [460]	validation_0-auc:0.82257
# [461]	validation_0-auc:0.82258
# [462]	validation_0-auc:0.82259
# [463]	validation_0-auc:0.82259
# [464]	validation_0-auc:0.82260
# [465]	validation_0-auc:0.82266
# [466]	validation_0-auc:0.82267
# [467]	validation_0-auc:0.82272
# [468]	validation_0-auc:0.82275
# [469]	validation_0-auc:0.82278
# [470]	validation_0-auc:0.82281
# [471]	validation_0-auc:0.82283
# [472]	validation_0-auc:0.82284
# [473]	validation_0-auc:0.82286
# [474]	validation_0-auc:0.82286
# [475]	validation_0-auc:0.82287
# [476]	validation_0-auc:0.82290
# [477]	validation_0-auc:0.82293
# [478]	validation_0-auc:0.82294
# [479]	validation_0-auc:0.82295
# [480]	validation_0-auc:0.82299
# [481]	validation_0-auc:0.82301
# [482]	validation_0-auc:0.82303
# [483]	validation_0-auc:0.82306
# [484]	validation_0-auc:0.82309
# [485]	validation_0-auc:0.82310
# [486]	validation_0-auc:0.82310
# [487]	validation_0-auc:0.82312
# [488]	validation_0-auc:0.82314
# [489]	validation_0-auc:0.82315
# [490]	validation_0-auc:0.82316
# [491]	validation_0-auc:0.82322
# [492]	validation_0-auc:0.82324
# [493]	validation_0-auc:0.82328
# [494]	validation_0-auc:0.82330
# [495]	validation_0-auc:0.82332
# [496]	validation_0-auc:0.82332
# [497]	validation_0-auc:0.82334
# [498]	validation_0-auc:0.82335
# [499]	validation_0-auc:0.82336
# [500]	validation_0-auc:0.82337
# [501]	validation_0-auc:0.82341
# [502]	validation_0-auc:0.82342
# [503]	validation_0-auc:0.82345
# [504]	validation_0-auc:0.82346
# [505]	validation_0-auc:0.82347
# [506]	validation_0-auc:0.82349
# [507]	validation_0-auc:0.82352
# [508]	validation_0-auc:0.82356
# [509]	validation_0-auc:0.82357
# [510]	validation_0-auc:0.82361
# [511]	validation_0-auc:0.82363
# [512]	validation_0-auc:0.82365
# [513]	validation_0-auc:0.82366
# [514]	validation_0-auc:0.82369
# [515]	validation_0-auc:0.82370
# [516]	validation_0-auc:0.82372
# [517]	validation_0-auc:0.82373
# [518]	validation_0-auc:0.82374
# [519]	validation_0-auc:0.82376
# [520]	validation_0-auc:0.82376
# [521]	validation_0-auc:0.82379
# [522]	validation_0-auc:0.82381
# [523]	validation_0-auc:0.82382
# [524]	validation_0-auc:0.82387
# [525]	validation_0-auc:0.82389
# [526]	validation_0-auc:0.82390
# [527]	validation_0-auc:0.82391
# [528]	validation_0-auc:0.82392
# [529]	validation_0-auc:0.82392
# [530]	validation_0-auc:0.82393
# [531]	validation_0-auc:0.82395
# [532]	validation_0-auc:0.82395
# [533]	validation_0-auc:0.82396
# [534]	validation_0-auc:0.82397
# [535]	validation_0-auc:0.82402
# [536]	validation_0-auc:0.82406
# [537]	validation_0-auc:0.82408
# [538]	validation_0-auc:0.82409
# [539]	validation_0-auc:0.82410
# [540]	validation_0-auc:0.82412
# [541]	validation_0-auc:0.82414
# [542]	validation_0-auc:0.82415
# [543]	validation_0-auc:0.82418
# [544]	validation_0-auc:0.82420
# [545]	validation_0-auc:0.82421
# [546]	validation_0-auc:0.82423
# [547]	validation_0-auc:0.82425
# [548]	validation_0-auc:0.82426
# [549]	validation_0-auc:0.82426
# [550]	validation_0-auc:0.82429
# [551]	validation_0-auc:0.82430
# [552]	validation_0-auc:0.82431
# [553]	validation_0-auc:0.82433
# [554]	validation_0-auc:0.82433
# [555]	validation_0-auc:0.82438
# [556]	validation_0-auc:0.82440
# [557]	validation_0-auc:0.82442
# [558]	validation_0-auc:0.82443
# [559]	validation_0-auc:0.82446
# [560]	validation_0-auc:0.82447
# [561]	validation_0-auc:0.82451
# [562]	validation_0-auc:0.82451
# [563]	validation_0-auc:0.82454
# [564]	validation_0-auc:0.82457
# [565]	validation_0-auc:0.82458
# [566]	validation_0-auc:0.82460
# [567]	validation_0-auc:0.82464
# [568]	validation_0-auc:0.82465
# [569]	validation_0-auc:0.82467
# [570]	validation_0-auc:0.82469
# [571]	validation_0-auc:0.82471
# [572]	validation_0-auc:0.82471
# [573]	validation_0-auc:0.82472
# [574]	validation_0-auc:0.82473
# [575]	validation_0-auc:0.82474
# [576]	validation_0-auc:0.82475
# [577]	validation_0-auc:0.82477
# [578]	validation_0-auc:0.82483
# [579]	validation_0-auc:0.82484
# [580]	validation_0-auc:0.82486
# [581]	validation_0-auc:0.82486
# [582]	validation_0-auc:0.82487
# [583]	validation_0-auc:0.82487
# [584]	validation_0-auc:0.82490
# [585]	validation_0-auc:0.82490
# [586]	validation_0-auc:0.82492
# [587]	validation_0-auc:0.82494
# [588]	validation_0-auc:0.82495
# [589]	validation_0-auc:0.82495
# [590]	validation_0-auc:0.82498
# [591]	validation_0-auc:0.82499
# [592]	validation_0-auc:0.82500
# [593]	validation_0-auc:0.82502
# [594]	validation_0-auc:0.82502
# [595]	validation_0-auc:0.82505
# [596]	validation_0-auc:0.82506
# [597]	validation_0-auc:0.82508
# [598]	validation_0-auc:0.82508
# [599]	validation_0-auc:0.82512
# [600]	validation_0-auc:0.82513
# [601]	validation_0-auc:0.82513
# [602]	validation_0-auc:0.82515
# [603]	validation_0-auc:0.82516
# [604]	validation_0-auc:0.82518
# [605]	validation_0-auc:0.82518
# [606]	validation_0-auc:0.82520
# [607]	validation_0-auc:0.82522
# [608]	validation_0-auc:0.82524
# [609]	validation_0-auc:0.82526
# [610]	validation_0-auc:0.82527
# [611]	validation_0-auc:0.82528
# [612]	validation_0-auc:0.82529
# [613]	validation_0-auc:0.82529
# [614]	validation_0-auc:0.82534
# [615]	validation_0-auc:0.82535
# [616]	validation_0-auc:0.82535
# [617]	validation_0-auc:0.82535
# [618]	validation_0-auc:0.82537
# [619]	validation_0-auc:0.82537
# [620]	validation_0-auc:0.82539
# [621]	validation_0-auc:0.82542
# [622]	validation_0-auc:0.82542
# [623]	validation_0-auc:0.82544
# [624]	validation_0-auc:0.82546
# [625]	validation_0-auc:0.82549
# [626]	validation_0-auc:0.82551
# [627]	validation_0-auc:0.82553
# [628]	validation_0-auc:0.82555
# [629]	validation_0-auc:0.82556
# [630]	validation_0-auc:0.82557
# [631]	validation_0-auc:0.82559
# [632]	validation_0-auc:0.82561
# [633]	validation_0-auc:0.82563
# [634]	validation_0-auc:0.82563
# [635]	validation_0-auc:0.82564
# [636]	validation_0-auc:0.82566
# [637]	validation_0-auc:0.82567
# [638]	validation_0-auc:0.82569
# [639]	validation_0-auc:0.82570
# [640]	validation_0-auc:0.82571
# [641]	validation_0-auc:0.82572
# [642]	validation_0-auc:0.82573
# [643]	validation_0-auc:0.82576
# [644]	validation_0-auc:0.82578
# [645]	validation_0-auc:0.82579
# [646]	validation_0-auc:0.82582
# [647]	validation_0-auc:0.82582
# [648]	validation_0-auc:0.82583
# [649]	validation_0-auc:0.82584
# [650]	validation_0-auc:0.82584
# [651]	validation_0-auc:0.82585
# [652]	validation_0-auc:0.82588
# [653]	validation_0-auc:0.82590
# [654]	validation_0-auc:0.82591
# [655]	validation_0-auc:0.82594
# [656]	validation_0-auc:0.82597
# [657]	validation_0-auc:0.82599
# [658]	validation_0-auc:0.82601
# [659]	validation_0-auc:0.82603
# [660]	validation_0-auc:0.82604
# [661]	validation_0-auc:0.82609
# [662]	validation_0-auc:0.82609
# [663]	validation_0-auc:0.82611
# [664]	validation_0-auc:0.82615
# [665]	validation_0-auc:0.82616
# [666]	validation_0-auc:0.82619
# [667]	validation_0-auc:0.82620
# [668]	validation_0-auc:0.82623
# [669]	validation_0-auc:0.82623
# [670]	validation_0-auc:0.82624
# [671]	validation_0-auc:0.82625
# [672]	validation_0-auc:0.82626
# [673]	validation_0-auc:0.82628
# [674]	validation_0-auc:0.82630
# [675]	validation_0-auc:0.82631
# [676]	validation_0-auc:0.82631
# [677]	validation_0-auc:0.82634
# [678]	validation_0-auc:0.82636
# [679]	validation_0-auc:0.82637
# [680]	validation_0-auc:0.82638
# [681]	validation_0-auc:0.82640
# [682]	validation_0-auc:0.82642
# [683]	validation_0-auc:0.82645
# [684]	validation_0-auc:0.82647
# [685]	validation_0-auc:0.82649
# [686]	validation_0-auc:0.82650
# [687]	validation_0-auc:0.82652
# [688]	validation_0-auc:0.82654
# [689]	validation_0-auc:0.82655
# [690]	validation_0-auc:0.82655
# [691]	validation_0-auc:0.82658
# [692]	validation_0-auc:0.82658
# [693]	validation_0-auc:0.82660
# [694]	validation_0-auc:0.82664
# [695]	validation_0-auc:0.82665
# [696]	validation_0-auc:0.82666
# [697]	validation_0-auc:0.82668
# [698]	validation_0-auc:0.82669
# [699]	validation_0-auc:0.82670
# [700]	validation_0-auc:0.82671
# [701]	validation_0-auc:0.82672
# [702]	validation_0-auc:0.82674
# [703]	validation_0-auc:0.82675
# [704]	validation_0-auc:0.82676
# [705]	validation_0-auc:0.82677
# [706]	validation_0-auc:0.82679
# [707]	validation_0-auc:0.82680
# [708]	validation_0-auc:0.82680
# [709]	validation_0-auc:0.82680
# [710]	validation_0-auc:0.82682
# [711]	validation_0-auc:0.82684
# [712]	validation_0-auc:0.82685
# [713]	validation_0-auc:0.82685
# [714]	validation_0-auc:0.82686
# [715]	validation_0-auc:0.82687
# [716]	validation_0-auc:0.82689
# [717]	validation_0-auc:0.82690
# [718]	validation_0-auc:0.82690
# [719]	validation_0-auc:0.82691
# [720]	validation_0-auc:0.82695
# [721]	validation_0-auc:0.82695
# [722]	validation_0-auc:0.82696
# [723]	validation_0-auc:0.82698
# [724]	validation_0-auc:0.82699
# [725]	validation_0-auc:0.82700
# [726]	validation_0-auc:0.82700
# [727]	validation_0-auc:0.82703
# [728]	validation_0-auc:0.82705
# [729]	validation_0-auc:0.82706
# [730]	validation_0-auc:0.82707
# [731]	validation_0-auc:0.82709
# [732]	validation_0-auc:0.82711
# [733]	validation_0-auc:0.82712
# [734]	validation_0-auc:0.82713
# [735]	validation_0-auc:0.82715
# [736]	validation_0-auc:0.82716
# [737]	validation_0-auc:0.82717
# [738]	validation_0-auc:0.82718
# [739]	validation_0-auc:0.82718
# [740]	validation_0-auc:0.82719
# [741]	validation_0-auc:0.82719
# [742]	validation_0-auc:0.82721
# [743]	validation_0-auc:0.82721
# [744]	validation_0-auc:0.82724
# [745]	validation_0-auc:0.82726
# [746]	validation_0-auc:0.82726
# [747]	validation_0-auc:0.82728
# [748]	validation_0-auc:0.82729
# [749]	validation_0-auc:0.82732
# [750]	validation_0-auc:0.82732
# [751]	validation_0-auc:0.82733
# [752]	validation_0-auc:0.82734
# [753]	validation_0-auc:0.82735
# [754]	validation_0-auc:0.82737
# [755]	validation_0-auc:0.82738
# [756]	validation_0-auc:0.82739
# [757]	validation_0-auc:0.82740
# [758]	validation_0-auc:0.82742
# [759]	validation_0-auc:0.82744
# [760]	validation_0-auc:0.82745
# [761]	validation_0-auc:0.82746
# [762]	validation_0-auc:0.82749
# [763]	validation_0-auc:0.82750
# [764]	validation_0-auc:0.82751
# [765]	validation_0-auc:0.82752
# [766]	validation_0-auc:0.82753
# [767]	validation_0-auc:0.82754
# [768]	validation_0-auc:0.82756
# [769]	validation_0-auc:0.82756
# [770]	validation_0-auc:0.82757
# [771]	validation_0-auc:0.82757
# [772]	validation_0-auc:0.82758
# [773]	validation_0-auc:0.82762
# [774]	validation_0-auc:0.82763
# [775]	validation_0-auc:0.82763
# [776]	validation_0-auc:0.82764
# [777]	validation_0-auc:0.82767
# [778]	validation_0-auc:0.82767
# [779]	validation_0-auc:0.82770
# [780]	validation_0-auc:0.82770
# [781]	validation_0-auc:0.82771
# [782]	validation_0-auc:0.82775
# [783]	validation_0-auc:0.82777
# [784]	validation_0-auc:0.82779
# [785]	validation_0-auc:0.82780
# [786]	validation_0-auc:0.82781
# [787]	validation_0-auc:0.82782
# [788]	validation_0-auc:0.82783
# [789]	validation_0-auc:0.82784
# [790]	validation_0-auc:0.82787
# [791]	validation_0-auc:0.82788
# [792]	validation_0-auc:0.82789
# [793]	validation_0-auc:0.82792
# [794]	validation_0-auc:0.82794
# [795]	validation_0-auc:0.82796
# [796]	validation_0-auc:0.82798
# [797]	validation_0-auc:0.82798
# [798]	validation_0-auc:0.82799
# [799]	validation_0-auc:0.82802
# [800]	validation_0-auc:0.82802
# [801]	validation_0-auc:0.82805
# [802]	validation_0-auc:0.82805
# [803]	validation_0-auc:0.82806
# [804]	validation_0-auc:0.82809
# [805]	validation_0-auc:0.82811
# [806]	validation_0-auc:0.82812
# [807]	validation_0-auc:0.82813
# [808]	validation_0-auc:0.82814
# [809]	validation_0-auc:0.82815
# [810]	validation_0-auc:0.82815
# [811]	validation_0-auc:0.82817
# [812]	validation_0-auc:0.82818
# [813]	validation_0-auc:0.82819
# [814]	validation_0-auc:0.82821
# [815]	validation_0-auc:0.82822
# [816]	validation_0-auc:0.82824
# [817]	validation_0-auc:0.82826
# [818]	validation_0-auc:0.82826
# [819]	validation_0-auc:0.82828
# [820]	validation_0-auc:0.82828
# [821]	validation_0-auc:0.82828
# [822]	validation_0-auc:0.82830
# [823]	validation_0-auc:0.82831
# [824]	validation_0-auc:0.82833
# [825]	validation_0-auc:0.82835
# [826]	validation_0-auc:0.82835
# [827]	validation_0-auc:0.82837
# [828]	validation_0-auc:0.82838
# [829]	validation_0-auc:0.82840
# [830]	validation_0-auc:0.82841
# [831]	validation_0-auc:0.82842
# [832]	validation_0-auc:0.82843
# [833]	validation_0-auc:0.82844
# [834]	validation_0-auc:0.82846
# [835]	validation_0-auc:0.82847
# [836]	validation_0-auc:0.82847
# [837]	validation_0-auc:0.82848
# [838]	validation_0-auc:0.82849
# [839]	validation_0-auc:0.82851
# [840]	validation_0-auc:0.82851
# [841]	validation_0-auc:0.82852
# [842]	validation_0-auc:0.82853
# [843]	validation_0-auc:0.82854
# [844]	validation_0-auc:0.82854
# [845]	validation_0-auc:0.82855
# [846]	validation_0-auc:0.82857
# [847]	validation_0-auc:0.82859
# [848]	validation_0-auc:0.82860
# [849]	validation_0-auc:0.82860
# [850]	validation_0-auc:0.82862
# [851]	validation_0-auc:0.82864
# [852]	validation_0-auc:0.82865
# [853]	validation_0-auc:0.82866
# [854]	validation_0-auc:0.82866
# [855]	validation_0-auc:0.82867
# [856]	validation_0-auc:0.82868
# [857]	validation_0-auc:0.82869
# [858]	validation_0-auc:0.82870
# [859]	validation_0-auc:0.82870
# [860]	validation_0-auc:0.82870
# [861]	validation_0-auc:0.82873
# [862]	validation_0-auc:0.82873
# [863]	validation_0-auc:0.82874
# [864]	validation_0-auc:0.82877
# [865]	validation_0-auc:0.82878
# [866]	validation_0-auc:0.82878
# [867]	validation_0-auc:0.82880
# [868]	validation_0-auc:0.82881
# [869]	validation_0-auc:0.82882
# [870]	validation_0-auc:0.82885
# [871]	validation_0-auc:0.82886
# [872]	validation_0-auc:0.82888
# [873]	validation_0-auc:0.82889
# [874]	validation_0-auc:0.82891
# [875]	validation_0-auc:0.82892
# [876]	validation_0-auc:0.82895
# [877]	validation_0-auc:0.82896
# [878]	validation_0-auc:0.82896
# [879]	validation_0-auc:0.82898
# [880]	validation_0-auc:0.82900
# [881]	validation_0-auc:0.82900
# [882]	validation_0-auc:0.82901
# [883]	validation_0-auc:0.82901
# [884]	validation_0-auc:0.82901
# [885]	validation_0-auc:0.82903
# [886]	validation_0-auc:0.82905
# [887]	validation_0-auc:0.82908
# [888]	validation_0-auc:0.82909
# [889]	validation_0-auc:0.82912
# [890]	validation_0-auc:0.82913
# [891]	validation_0-auc:0.82914
# [892]	validation_0-auc:0.82915
# [893]	validation_0-auc:0.82917
# [894]	validation_0-auc:0.82917
# [895]	validation_0-auc:0.82918
# [896]	validation_0-auc:0.82919
# [897]	validation_0-auc:0.82921
# [898]	validation_0-auc:0.82923
# [899]	validation_0-auc:0.82925
# [900]	validation_0-auc:0.82926
# [901]	validation_0-auc:0.82927
# [902]	validation_0-auc:0.82928
# [903]	validation_0-auc:0.82928
# [904]	validation_0-auc:0.82931
# [905]	validation_0-auc:0.82931
# [906]	validation_0-auc:0.82933
# [907]	validation_0-auc:0.82934
# [908]	validation_0-auc:0.82936
# [909]	validation_0-auc:0.82937
# [910]	validation_0-auc:0.82938
# [911]	validation_0-auc:0.82940
# [912]	validation_0-auc:0.82940
# [913]	validation_0-auc:0.82941
# [914]	validation_0-auc:0.82942
# [915]	validation_0-auc:0.82942
# [916]	validation_0-auc:0.82943
# [917]	validation_0-auc:0.82945
# [918]	validation_0-auc:0.82945
# [919]	validation_0-auc:0.82947
# [920]	validation_0-auc:0.82947
# [921]	validation_0-auc:0.82948
# [922]	validation_0-auc:0.82948
# [923]	validation_0-auc:0.82949
# [924]	validation_0-auc:0.82949
# [925]	validation_0-auc:0.82950
# [926]	validation_0-auc:0.82951
# [927]	validation_0-auc:0.82952
# [928]	validation_0-auc:0.82952
# [929]	validation_0-auc:0.82954
# [930]	validation_0-auc:0.82954
# [931]	validation_0-auc:0.82955
# [932]	validation_0-auc:0.82958
# [933]	validation_0-auc:0.82958
# [934]	validation_0-auc:0.82961
# [935]	validation_0-auc:0.82962
# [936]	validation_0-auc:0.82962
# [937]	validation_0-auc:0.82963
# [938]	validation_0-auc:0.82967
# [939]	validation_0-auc:0.82968
# [940]	validation_0-auc:0.82968
# [941]	validation_0-auc:0.82969
# [942]	validation_0-auc:0.82969
# [943]	validation_0-auc:0.82971
# [944]	validation_0-auc:0.82972
# [945]	validation_0-auc:0.82973
# [946]	validation_0-auc:0.82973
# [947]	validation_0-auc:0.82973
# [948]	validation_0-auc:0.82974
# [949]	validation_0-auc:0.82976
# [950]	validation_0-auc:0.82977
# [951]	validation_0-auc:0.82979
# [952]	validation_0-auc:0.82980
# [953]	validation_0-auc:0.82981
# [954]	validation_0-auc:0.82982
# [955]	validation_0-auc:0.82984
# [956]	validation_0-auc:0.82985
# [957]	validation_0-auc:0.82986
# [958]	validation_0-auc:0.82987
# [959]	validation_0-auc:0.82987
# [960]	validation_0-auc:0.82988
# [961]	validation_0-auc:0.82988
# [962]	validation_0-auc:0.82989
# [963]	validation_0-auc:0.82989
# [964]	validation_0-auc:0.82991
# [965]	validation_0-auc:0.82993
# [966]	validation_0-auc:0.82994
# [967]	validation_0-auc:0.82995
# [968]	validation_0-auc:0.82996
# [969]	validation_0-auc:0.82997
# [970]	validation_0-auc:0.82997
# [971]	validation_0-auc:0.83000
# [972]	validation_0-auc:0.83002
# [973]	validation_0-auc:0.83003
# [974]	validation_0-auc:0.83004
# [975]	validation_0-auc:0.83006
# [976]	validation_0-auc:0.83007
# [977]	validation_0-auc:0.83010
# [978]	validation_0-auc:0.83012
# [979]	validation_0-auc:0.83013
# [980]	validation_0-auc:0.83015
# [981]	validation_0-auc:0.83017
# [982]	validation_0-auc:0.83017
# [983]	validation_0-auc:0.83018
# [984]	validation_0-auc:0.83019
# [985]	validation_0-auc:0.83019
# [986]	validation_0-auc:0.83019
# [987]	validation_0-auc:0.83022
# [988]	validation_0-auc:0.83022
# [989]	validation_0-auc:0.83023
# [990]	validation_0-auc:0.83023
# [991]	validation_0-auc:0.83023
# [992]	validation_0-auc:0.83023
# [993]	validation_0-auc:0.83024
# [994]	validation_0-auc:0.83026
# [995]	validation_0-auc:0.83027
# [996]	validation_0-auc:0.83028
# [997]	validation_0-auc:0.83028
# [998]	validation_0-auc:0.83029
# [999]	validation_0-auc:0.83030
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/xgboost/sklearn.py:1028: UserWarning: [06:12:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   self.get_booster().save_model(fname)
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/xgboost/sklearn.py:1028: UserWarning: [06:12:48] WARNING: /workspace/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/xgboost/core.py:729: UserWarning: [06:12:48] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# XGBoost: Accuracy: 0.7479072727272728
# XGBoost: ROC-AUC : 0.8302976379457191

# %%
class MLP(nn.Module):
    def __init__(self, in_dim=28):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1),
            nn.Sigmoid(), # BCE Loss.
        )
    def forward(self, x):
        return self.net(x)
device = "cuda" if torch.cuda.is_available() else "cpu"
model = MLP(in_dim=X_train.shape[1]).to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

train_ds = TensorDataset(torch.tensor(X_train), torch.tensor(y_train, dtype=torch.float32))
val_ds   = TensorDataset(torch.tensor(X_val),   torch.tensor(y_val,   dtype=torch.float32))
train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=1024, shuffle=False)

best_auc, patience, patience_limit = 0, 0, 10
for epoch in range(100):
    model.train()
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device).unsqueeze(1)
        optimizer.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        optimizer.step()
    model.eval()
    with torch.no_grad():
        preds = []
        for xb, _ in val_loader:
            xb = xb.to(device)
            preds.append(model(xb).cpu().numpy())
        preds = np.vstack(preds).ravel()
        auc = roc_auc_score(y_val, preds)
        acc = accuracy_score(y_val,preds)
        #print(f"MLP AUC:{auc} ACC : {acc},{epoch}epoch.")
    if auc > best_auc:
        best_auc, patience = auc, 0
        torch.save(model.state_dict(), "./save/MLP/mlp.pt")
    else:
        patience += 1
    if patience >= patience_limit:
        print(f"MLP trian Early Stop : {epoch}epoch.")
        break
print("MLP best ROC-AUC:", best_auc)
# Out:
# MLP best ROC-AUC: 0.8423877616119122

# %%
tabnet = TabNetClassifier(
    n_d=64, n_a=64, n_steps=5,
    gamma=1.5, n_independent=2, n_shared=2,
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-3),
    scheduler_params={"step_size":50, "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    verbose=1,
    device_name=device, 
)

tabnet.fit(
    X_train=X_train, y_train=y_train,
    eval_set=[(X_val, y_val)],
    eval_name=["val"],
    eval_metric=["auc"],
    max_epochs=200,
    patience=20,
    batch_size=1024, virtual_batch_size=128,
)

tab_pred = (tabnet.predict_proba(X_val)[:, 1] > 0.5).astype(int)
print("TabNet Accuracy:", accuracy_score(y_val, tab_pred))
print("TabNet ROC-AUC :", roc_auc_score(y_val, tabnet.predict_proba(X_val)[:, 1]))
# Out:
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.61265 | val_auc: 0.76576 |  0:03:09s
# epoch 1  | loss: 0.56799 | val_auc: 0.79087 |  0:06:18s
# epoch 2  | loss: 0.54789 | val_auc: 0.80576 |  0:09:22s
# epoch 3  | loss: 0.52922 | val_auc: 0.82323 |  0:12:27s
# epoch 4  | loss: 0.51327 | val_auc: 0.83274 |  0:15:40s
# epoch 5  | loss: 0.5034  | val_auc: 0.83898 |  0:18:49s
# epoch 6  | loss: 0.49586 | val_auc: 0.84358 |  0:21:59s
# epoch 7  | loss: 0.49134 | val_auc: 0.84721 |  0:25:05s
# epoch 8  | loss: 0.4874  | val_auc: 0.84907 |  0:28:09s
# epoch 9  | loss: 0.4847  | val_auc: 0.85158 |  0:31:20s
# epoch 10 | loss: 0.48295 | val_auc: 0.852   |  0:34:27s
# epoch 11 | loss: 0.48126 | val_auc: 0.85219 |  0:37:32s
# epoch 12 | loss: 0.47945 | val_auc: 0.85435 |  0:40:40s
# epoch 13 | loss: 0.47792 | val_auc: 0.85537 |  0:43:47s
# epoch 14 | loss: 0.47701 | val_auc: 0.85638 |  0:46:52s
# epoch 15 | loss: 0.47509 | val_auc: 0.85749 |  0:49:56s
# epoch 16 | loss: 0.47414 | val_auc: 0.85759 |  0:53:02s
# epoch 17 | loss: 0.4736  | val_auc: 0.85759 |  0:56:06s
# epoch 18 | loss: 0.47238 | val_auc: 0.85838 |  0:59:10s
# epoch 19 | loss: 0.47136 | val_auc: 0.85685 |  1:02:18s
# epoch 20 | loss: 0.47082 | val_auc: 0.85921 |  1:05:23s
# epoch 21 | loss: 0.46942 | val_auc: 0.86068 |  1:08:31s
# epoch 22 | loss: 0.46806 | val_auc: 0.86152 |  1:11:37s
# epoch 23 | loss: 0.46715 | val_auc: 0.86137 |  1:14:41s
# epoch 24 | loss: 0.46634 | val_auc: 0.86181 |  1:17:44s
# epoch 25 | loss: 0.46575 | val_auc: 0.86213 |  1:20:51s
# epoch 26 | loss: 0.46522 | val_auc: 0.86234 |  1:23:58s
# epoch 27 | loss: 0.46465 | val_auc: 0.86217 |  1:27:01s
# epoch 28 | loss: 0.46481 | val_auc: 0.86203 |  1:30:06s
# epoch 29 | loss: 0.46447 | val_auc: 0.86232 |  1:33:11s
# epoch 30 | loss: 0.464   | val_auc: 0.86252 |  1:36:15s
# epoch 31 | loss: 0.46376 | val_auc: 0.863   |  1:39:22s
# epoch 32 | loss: 0.46388 | val_auc: 0.86324 |  1:42:26s
# epoch 33 | loss: 0.46355 | val_auc: 0.86364 |  1:45:32s
# epoch 34 | loss: 0.46305 | val_auc: 0.86359 |  1:48:38s
# epoch 35 | loss: 0.46257 | val_auc: 0.86419 |  1:51:48s
# epoch 36 | loss: 0.46245 | val_auc: 0.86303 |  1:54:55s
# epoch 37 | loss: 0.46245 | val_auc: 0.86391 |  1:58:06s
# epoch 38 | loss: 0.46293 | val_auc: 0.86393 |  2:01:10s
# epoch 39 | loss: 0.46165 | val_auc: 0.86358 |  2:04:15s
# epoch 40 | loss: 0.46139 | val_auc: 0.86428 |  2:07:22s
# epoch 41 | loss: 0.46117 | val_auc: 0.86323 |  2:10:27s
# epoch 42 | loss: 0.46135 | val_auc: 0.86434 |  2:13:32s
# epoch 43 | loss: 0.46242 | val_auc: 0.86373 |  2:16:42s
# epoch 44 | loss: 0.46236 | val_auc: 0.8635  |  2:19:46s
# epoch 45 | loss: 0.46155 | val_auc: 0.8648  |  2:22:53s
# epoch 46 | loss: 0.4613  | val_auc: 0.86485 |  2:25:57s
# epoch 47 | loss: 0.45958 | val_auc: 0.86519 |  2:29:07s
# epoch 48 | loss: 0.45922 | val_auc: 0.8658  |  2:32:16s
# epoch 49 | loss: 0.46019 | val_auc: 0.86564 |  2:35:24s
# epoch 50 | loss: 0.45848 | val_auc: 0.86557 |  2:38:31s
# epoch 51 | loss: 0.45826 | val_auc: 0.86601 |  2:41:37s
# epoch 52 | loss: 0.45799 | val_auc: 0.86621 |  2:44:43s
# epoch 53 | loss: 0.45826 | val_auc: 0.86598 |  2:47:49s
# epoch 54 | loss: 0.45826 | val_auc: 0.86547 |  2:50:57s
# epoch 55 | loss: 0.4581  | val_auc: 0.86616 |  2:54:03s
# epoch 56 | loss: 0.45795 | val_auc: 0.86574 |  2:57:11s
# epoch 57 | loss: 0.45789 | val_auc: 0.86566 |  3:00:16s
# epoch 58 | loss: 0.45853 | val_auc: 0.86617 |  3:03:23s
# epoch 59 | loss: 0.45801 | val_auc: 0.86592 |  3:06:28s
# epoch 60 | loss: 0.45773 | val_auc: 0.86591 |  3:09:36s
# epoch 61 | loss: 0.45742 | val_auc: 0.86605 |  3:12:45s
# epoch 62 | loss: 0.45739 | val_auc: 0.86599 |  3:15:53s
# epoch 63 | loss: 0.45725 | val_auc: 0.86615 |  3:18:57s
# epoch 64 | loss: 0.45692 | val_auc: 0.86653 |  3:22:02s
# epoch 65 | loss: 0.45708 | val_auc: 0.86647 |  3:25:06s
# epoch 66 | loss: 0.45745 | val_auc: 0.86597 |  3:28:10s
# epoch 67 | loss: 0.45722 | val_auc: 0.86609 |  3:31:15s
# epoch 68 | loss: 0.45632 | val_auc: 0.86704 |  3:34:22s
# epoch 69 | loss: 0.45609 | val_auc: 0.86689 |  3:37:29s
# epoch 70 | loss: 0.45586 | val_auc: 0.86707 |  3:40:34s
# epoch 71 | loss: 0.45562 | val_auc: 0.86704 |  3:43:44s
# epoch 72 | loss: 0.45553 | val_auc: 0.86745 |  3:46:51s
# epoch 73 | loss: 0.45554 | val_auc: 0.86695 |  3:49:57s
# epoch 74 | loss: 0.45575 | val_auc: 0.86659 |  3:53:05s
# epoch 75 | loss: 0.45611 | val_auc: 0.86692 |  3:56:09s
# epoch 76 | loss: 0.45612 | val_auc: 0.86629 |  3:59:17s
# epoch 77 | loss: 0.45634 | val_auc: 0.86611 |  4:02:23s
# epoch 78 | loss: 0.45635 | val_auc: 0.86646 |  4:05:33s
# epoch 79 | loss: 0.45546 | val_auc: 0.86701 |  4:08:37s
# epoch 80 | loss: 0.45592 | val_auc: 0.86659 |  4:11:47s
# epoch 81 | loss: 0.45613 | val_auc: 0.86664 |  4:14:52s
# epoch 82 | loss: 0.45547 | val_auc: 0.86749 |  4:17:57s
# epoch 83 | loss: 0.45474 | val_auc: 0.86724 |  4:20:59s
# epoch 84 | loss: 0.4546  | val_auc: 0.86779 |  4:24:08s
# epoch 85 | loss: 0.4545  | val_auc: 0.86776 |  4:27:16s
# epoch 86 | loss: 0.45431 | val_auc: 0.86751 |  4:30:22s
# epoch 87 | loss: 0.45421 | val_auc: 0.86773 |  4:33:27s
# epoch 88 | loss: 0.45415 | val_auc: 0.86733 |  4:36:35s
# epoch 89 | loss: 0.45402 | val_auc: 0.86692 |  4:39:42s
# epoch 90 | loss: 0.45403 | val_auc: 0.86759 |  4:42:47s
# epoch 91 | loss: 0.45393 | val_auc: 0.86685 |  4:45:53s
# epoch 92 | loss: 0.45384 | val_auc: 0.86675 |  4:49:00s
# epoch 93 | loss: 0.45372 | val_auc: 0.86777 |  4:52:04s
# epoch 94 | loss: 0.4537  | val_auc: 0.86775 |  4:55:14s
# epoch 95 | loss: 0.45357 | val_auc: 0.86799 |  4:58:20s
# epoch 96 | loss: 0.45345 | val_auc: 0.86737 |  5:01:25s
# epoch 97 | loss: 0.45343 | val_auc: 0.8681  |  5:04:30s
# epoch 98 | loss: 0.45331 | val_auc: 0.86817 |  5:07:34s
# epoch 99 | loss: 0.45328 | val_auc: 0.86796 |  5:10:42s
# epoch 100| loss: 0.45283 | val_auc: 0.86799 |  5:13:50s
# epoch 101| loss: 0.45275 | val_auc: 0.86804 |  5:16:56s
# epoch 102| loss: 0.45271 | val_auc: 0.86825 |  5:20:01s
# epoch 103| loss: 0.45273 | val_auc: 0.86801 |  5:23:05s
# epoch 104| loss: 0.45262 | val_auc: 0.86812 |  5:26:10s
# epoch 105| loss: 0.45246 | val_auc: 0.86837 |  5:29:14s
# epoch 106| loss: 0.45243 | val_auc: 0.86819 |  5:32:22s
# epoch 107| loss: 0.45246 | val_auc: 0.86823 |  5:35:27s
# epoch 108| loss: 0.45231 | val_auc: 0.86822 |  5:38:33s
# epoch 109| loss: 0.45226 | val_auc: 0.86806 |  5:41:38s
# epoch 110| loss: 0.4522  | val_auc: 0.86797 |  5:44:42s
# epoch 111| loss: 0.45225 | val_auc: 0.86795 |  5:47:49s
# epoch 112| loss: 0.45229 | val_auc: 0.86832 |  5:50:51s
# epoch 113| loss: 0.45215 | val_auc: 0.86841 |  5:53:59s
# epoch 114| loss: 0.45207 | val_auc: 0.86853 |  5:57:09s
# epoch 115| loss: 0.45267 | val_auc: 0.86851 |  6:00:17s
# epoch 116| loss: 0.45242 | val_auc: 0.86816 |  6:03:18s
# epoch 117| loss: 0.45233 | val_auc: 0.86835 |  6:06:25s
# epoch 118| loss: 0.45225 | val_auc: 0.86872 |  6:09:30s
# epoch 119| loss: 0.4522  | val_auc: 0.86844 |  6:12:35s
# epoch 120| loss: 0.45235 | val_auc: 0.86834 |  6:15:37s
# epoch 121| loss: 0.4522  | val_auc: 0.86861 |  6:18:41s
# epoch 122| loss: 0.45203 | val_auc: 0.86852 |  6:21:46s
# epoch 123| loss: 0.45192 | val_auc: 0.86886 |  6:24:53s
# epoch 124| loss: 0.45191 | val_auc: 0.8686  |  6:27:55s
# epoch 125| loss: 0.4519  | val_auc: 0.8687  |  6:31:06s
# epoch 126| loss: 0.45179 | val_auc: 0.86886 |  6:34:14s
# epoch 127| loss: 0.45181 | val_auc: 0.86874 |  6:37:18s
# epoch 128| loss: 0.45169 | val_auc: 0.86838 |  6:40:25s
# epoch 129| loss: 0.45177 | val_auc: 0.86843 |  6:43:26s
# epoch 130| loss: 0.45186 | val_auc: 0.86796 |  6:46:30s
# epoch 131| loss: 0.45183 | val_auc: 0.86863 |  6:49:34s
# epoch 132| loss: 0.45157 | val_auc: 0.86862 |  6:52:38s
# epoch 133| loss: 0.45151 | val_auc: 0.8688  |  6:55:44s
# epoch 134| loss: 0.45157 | val_auc: 0.86883 |  6:58:49s
# epoch 135| loss: 0.45146 | val_auc: 0.86807 |  7:01:52s
# epoch 136| loss: 0.45141 | val_auc: 0.86854 |  7:04:55s
# epoch 137| loss: 0.45139 | val_auc: 0.86828 |  7:08:01s
# epoch 138| loss: 0.45134 | val_auc: 0.86877 |  7:11:02s
# epoch 139| loss: 0.45128 | val_auc: 0.86843 |  7:14:06s
# epoch 140| loss: 0.45122 | val_auc: 0.86854 |  7:17:12s
# epoch 141| loss: 0.45125 | val_auc: 0.86816 |  7:20:19s
# epoch 142| loss: 0.45126 | val_auc: 0.86849 |  7:23:24s
# epoch 143| loss: 0.45126 | val_auc: 0.86827 |  7:26:27s
# epoch 144| loss: 0.45112 | val_auc: 0.86825 |  7:29:31s
# epoch 145| loss: 0.45116 | val_auc: 0.86838 |  7:32:34s
# epoch 146| loss: 0.45098 | val_auc: 0.86871 |  7:35:40s
#
# Early stopping occurred at epoch 146 with best_epoch = 126 and best_val_auc = 0.86886
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# TabNet Accuracy: 0.7832968181818182
# TabNet ROC-AUC : 0.8688608324332339

# %%
tabnet.save_model("./save/TABNET/tabnet_best_model") # zip 으로 저장됨.
# Out:
# Successfully saved model at ./save/TABNET/tabnet_best_model.zip
# './save/TABNET/tabnet_best_model.zip'

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

loaded_tabnet = TabNetClassifier()
loaded_tabnet.load_model("./save/TABNET/tabnet_best_model.zip")

loaded_pred = (loaded_tabnet.predict_proba(X_val)[:, 1] > 0.5).astype(int)
print("Loaded Accuracy:", accuracy_score(y_val, loaded_pred))
print("Loaded ROC-AUC :", roc_auc_score(y_val, loaded_tabnet.predict_proba(X_val)[:, 1]))
# Out:
# /home/shlee/Desktop/spea_arnormal_detection/spea_arnormal_detection_env/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# Loaded Accuracy: 0.7832968181818182
# Loaded ROC-AUC : 0.8688608324332339
